# %%
user = '001'
userdata = 'C:/Users/MyPC/Desktop/Projet Gps/Data/001/Trajectory/'



import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os

# Enable inline plotting

# Enable inline plotting
# Enable inline plotting
names = ['lat','lng','zero','alt','days','date','time']

test =pd.read_csv('C:/Users/MyPC/Desktop/Projet Gps/Data/001/Trajectory/20081214235553.plt',header=6,names=names,index_col=False)
df_min= pd.read
'C:/Users/MyPC/Desktop/Projet Gps/AutreP/Livraison 1_CSV/corrected_gps_information_new.csv'
# %matplotlib inline
filelist = os.listdir(userdata) 
names = ['lat','lng','zero','alt','days','date','time']
df_list = [pd.read_csv(userdata + f,header=6,names=names,index_col=False) for f in filelist]
df = pd.concat(df_list, ignore_index=True)

# delete unused column
df.drop(['zero', 'days'], axis=1, inplace=True)

# data is recorded every 1~5 seconds, which is too frequent. Reduce it to every minute
df_min = df.iloc[::6, :]

print(df_min.head(10))
print ('Total GPS points: ' + str(df_min.shape[0]))

import gmplot
# declare the center of the map, and how much we want the map zoomed in
gmap = gmplot.GoogleMapPlotter(df_min.lat[0], df_min.lng[0], 11)
gmap.plot(df_min.lat, df_min.lng)
gmap.draw("user001_map.html")
# Out:
#           lat         lng  alt        date      time
# 0   40.013907  116.306488  168  2008-10-23  23:41:06
# 6   40.013872  116.306527  162  2008-10-23  23:41:36
# 12  40.013853  116.306535  157  2008-10-23  23:42:01
# 18  40.013838  116.306549  142  2008-10-23  23:42:31
# 24  40.013825  116.306557  141  2008-10-23  23:42:51
# 30  40.013809  116.306561  129  2008-10-23  23:43:16
# 36  40.013992  116.306323  125  2008-10-23  23:43:46
# 42  40.014016  116.305706  129  2008-10-23  23:44:15
# 48  40.013796  116.306278  141  2008-10-23  23:44:41
# 54  40.013521  116.306683  140  2008-10-23  23:45:09
# Total GPS points: 17930

# %%
from sklearn.cluster import DBSCAN
from sklearn import metrics

# represent GPS points as (lat, lon)
coords = df_min.as_matrix(columns=['lat', 'lng'])
coords1= df_min.as_matrix(columns=['lat', 'lng', 'alt', 'date','time'])

# earth's radius in km
kms_per_radian = 6371.0088
# define epsilon as 0.5 kilometers, converted to radians for use by haversine
epsilon = 0.5 / kms_per_radian

# eps is the max distance that points can be from each other to be considered in a cluster
# min_samples is the minimum cluster size (everything else is classified as noise)
db = DBSCAN(eps=epsilon, min_samples=100, algorithm='ball_tree', metric='haversine').fit(np.radians(coords))
cluster_labels = db.labels_
# get the number of clusters (ignore noisy samples which are given the label -1)
num_clusters = len(set(cluster_labels) - set([-1]))

print ('Clustered ' + str(len(df_min)) + ' points to ' + str(num_clusters) + ' clusters')

# turn the clusters in to a pandas series
clusters = pd.Series([coords[cluster_labels == n] for n in range(num_clusters)])
# Out:
# Clustered 17930 points to 11 clusters

# %%
from shapely.geometry import MultiPoint
from geopy.distance import great_circle
def get_centermost_point(cluster):
    centroid = (MultiPoint(cluster).centroid.x, MultiPoint(cluster).centroid.y)
    centermost_point = min(cluster, key=lambda point: great_circle(point, centroid).m)
    return tuple(centermost_point)

# get the centroid point for each cluster
centermost_points = clusters.map(get_centermost_point)
lats, lons = zip(*centermost_points)
rep_points = pd.DataFrame({'lon':lons, 'lat':lats})

# %%
fig, ax = plt.subplots(figsize=[10, 6])
rs_scatter = ax.scatter(rep_points['lon'][0], rep_points['lat'][0], c='#99cc99', edgecolor='None', alpha=0.7, s=450)
ax.scatter(rep_points['lon'][1], rep_points['lat'][1], c='#99cc99', edgecolor='None', alpha=0.7, s=250)
ax.scatter(rep_points['lon'][2], rep_points['lat'][2], c='#99cc99', edgecolor='None', alpha=0.7, s=250)
ax.scatter(rep_points['lon'][3], rep_points['lat'][3], c='#99cc99', edgecolor='None', alpha=0.7, s=150)
df_scatter = ax.scatter(df_min['lng'], df_min['lat'], c='k', alpha=0.9, s=3)
ax.set_title('Full GPS trace vs. DBSCAN clusters')
ax.set_xlabel('Longitude')
ax.set_ylabel('Latitude')
ax.legend([df_scatter, rs_scatter], ['GPS points', 'Cluster centers'], loc='upper right')

labels = ['cluster{0}'.format(i) for i in range(1, num_clusters+1)]
for label, x, y in zip(labels, rep_points['lon'], rep_points['lat']):
    plt.annotate(
        label, 
        xy = (x, y), xytext = (-25, -30),
        textcoords = 'offset points', ha = 'right', va = 'bottom',
        bbox = dict(boxstyle = 'round,pad=0.5', fc = 'white', alpha = 0.5),
        arrowprops = dict(arrowstyle = '->', connectionstyle = 'arc3,rad=0'))

plt.show()

# %%
lats
# Out:
# (39.999484000000002,
#  39.994188000000001,
#  40.001321999999995,
#  39.990646000000005,
#  40.032206000000002,
#  40.073015999999996,
#  39.976682000000004,
#  39.952184000000003,
#  39.96613,
#  39.908577000000001,
#  39.961728999999998)

# %%
rep_points
# Out:
#           lat         lon
# 0   39.999484  116.318399
# 1   39.994188  116.199206
# 2   40.001322  116.171410
# 3   39.990646  116.188471
# 4   40.032206  116.312929
# 5   40.073016  116.338559
# 6   39.976682  116.383428
# 7   39.952184  116.329903
# 8   39.966130  116.360070
# 9   39.908577  116.409670
# 10  39.961729  116.438177

# %%
# Get the hours for each cluster
M = []
def myfunc(row):
    t = df_min[(df_min['lat']==row[0]) & (df_min['lng']==row[1])]['time'].iloc[0]
    return t[:t.index(':')]
for i in range(num_clusters):
    hours = np.apply_along_axis(myfunc, 1, clusters[i]).tolist()
    M.append(map(int, hours))

# %%
f, axarr = plt.subplots(4, sharex=True, figsize=(6,10))
axarr[0].hist(M[0])
axarr[0].text(20, 1600, "cluster 1")
axarr[1].hist(M[1])
axarr[1].text(20, 50, "cluster 2")
axarr[2].hist(M[2])
axarr[2].text(20, 40, "cluster 3")
axarr[3].hist(M[3])
axarr[3].text(20, 50, "cluster 4")
axarr[3].set_xlabel("Hours of a day")
plt.xticks(np.arange(0, 25, 2.0))
f.text(0.04, 0.5, '# of GPS points', va='center', rotation='vertical')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-68-2c94ac6c2c33> in <module>()
#       1 f, axarr = plt.subplots(4, sharex=True, figsize=(6,10))
# ----> 2 axarr[0].hist(M[0])
#       3 axarr[0].text(20, 1600, "cluster 1")
#       4 axarr[1].hist(M[1])
#       5 axarr[1].text(20, 50, "cluster 2")
#
# D:\Programmes\Anaconda2\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
#    1708                     warnings.warn(msg % (label_namer, func.__name__),
#    1709                                   RuntimeWarning, stacklevel=2)
# -> 1710             return func(ax, *args, **kwargs)
#    1711         pre_doc = inner.__doc__
#    1712         if pre_doc is None:
#
# D:\Programmes\Anaconda2\lib\site-packages\matplotlib\axes\_axes.py in hist(***failed resolving arguments***)
#    6144
#    6145         # process the unit information
# ...

# %%
fig, ax = plt.subplots(figsize=[10, 6])
rs_scatter = ax.scatter(rep_points['lon'][0], rep_points['lat'][0], c='#99cc99', edgecolor='None', alpha=0.7, s=450)
ax.scatter(rep_points['lon'][1], rep_points['lat'][1], c='#99cc99', edgecolor='None', alpha=0.7, s=250)
ax.scatter(rep_points['lon'][2], rep_points['lat'][2], c='#99cc99', edgecolor='None', alpha=0.7, s=250)
ax.scatter(rep_points['lon'][3], rep_points['lat'][3], c='#99cc99', edgecolor='None', alpha=0.7, s=150)
df_scatter = ax.scatter(df_min['lng'], df_min['lat'], c='k', alpha=0.9, s=3)
ax.set_title('Full GPS trace vs. DBSCAN clusters')
ax.set_xlabel('Longitude')
ax.set_ylabel('Latitude')
ax.legend([df_scatter, rs_scatter], ['GPS points', 'Cluster centers'], loc='upper right')

labels = ['Work', 'Home', 'Home 2']
for label, x, y in zip(labels, rep_points['lon'][:num_clusters-1], rep_points['lat'][:num_clusters-1]):
    plt.annotate(
        label, 
        xy = (x, y), xytext = (-25, -30),
        textcoords = 'offset points', ha = 'right', va = 'bottom',
        bbox = dict(boxstyle = 'round,pad=0.5', fc = 'white', alpha = 0.5),
        arrowprops = dict(arrowstyle = '->', connectionstyle = 'arc3,rad=0'))

plt.show()

# %%
gmap = gmplot.GoogleMapPlotter(rep_points['lat'][0], rep_points['lon'][0], 11)
gmap.plot(df_min.lat, df_min.lng)
gmap.heatmap(rep_points['lat'][:3], rep_points['lon'][:3], radius=20)
gmap.draw("user001_work_home.html")

# %%
### juste garder les mooves

moove = pd.Series([coords1[cluster_labels == -1] ])
print(moove)
# Out:
# 0    [[39.996342, 116.29777800000001, 179, 2008-10-...
# dtype: object

# %%
tab=[]

for i in range(0, len(moove[0])-1):
    
    for x in moove[0][i]:
        tab.append(x)


tab1 = [element for element in tab if tab.index(element)%5==0]
tab2 = [element for element in tab if tab.index(element)%5==1]
tab3 = [element for element in tab if tab.index(element)%5==2]
tab4 = [element for element in tab if tab.index(element)%5==3]
tab5 = [element for element in tab if tab.index(element)%5==4]

D1= pd.DataFrame(tab1)
D2=pd.DataFrame(tab2)
D3=pd.DataFrame(tab3)
D4=pd.DataFrame(tab4)
D5=pd.DataFrame(tab5)

result = pd.concat([D1, D2, D3,D4,D5], axis=1)
result.columns=['lat','lng','alt','date','heure']
result
# Out:
#             lat         lng  alt        date     heure
# 0     39.996342  116.297778  179  2008-10-25  00:37:58
# 1     39.996295  116.296932  191  2008-10-25  00:38:16
# 2     39.996235  116.296109  206  2008-10-25  00:38:34
# 3     39.996211  116.295883  202  2008-10-25  00:38:59
# 4     39.996161  116.295521  175  2008-10-25  00:39:24
# 5     39.996175  116.295234  172  2008-10-25  00:39:49
# 6     39.996134  116.294540  158  2008-10-25  00:40:11
# 7     39.996187  116.294157  185  2008-10-25  00:40:41
# 8     39.996257  116.293649  193  2008-10-25  00:41:11
# 9     39.996158  116.293073  191  2008-10-25  00:41:40
# 10    39.996070  116.292479  182  2008-10-25  00:42:08
# 11    39.996019  116.291703  194  2008-10-25  00:42:33
# 12    39.996008  116.291281  210  2008-10-25  00:42:57
# 13    39.995979  116.291175  204  2008-10-25  00:43:22
# 14    39.995920  116.290330  208  2008-10-25  00:43:42
# 15    39.995943  116.289437  222  2008-10-25  00:43:57
# ...

# %%
 plt.plot(result.iloc[:,0], result.iloc[:,1])

# %%
plt.plot(coords[:,0], coords[:,1])

# %%
plt.plot(test['lat'].values , test['lng'].values)

# %%
### convertir données en x y z 
import math
from math import cos
from math import sin
acc= pd.DataFrame()

acc['r']= 6371000+ result['alt']/3.28084
acc['x']=0
acc['y']=0
acc['z']=0
f = 1/298.257223563


tab2=[]
for i in range(0, len(result)-1):
    r= acc['r'].iloc[i]
    acc['x'].iloc[i] =r*float(math.cos(result['lat'].iloc[i])*math.cos(result['lng'].iloc[i]))
    acc['y'].iloc[i] =r*float(math.cos(result['lat'].iloc[i])*math.sin(result['lng'].iloc[i]))
    acc['z'].iloc[i] =r*float(math.sin(result['lat'].iloc[i]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-70-225f3d9b8d07> in <module>()
#       5 acc= pd.DataFrame()
#       6
# ----> 7 acc['r']= 6371000+ result['alt']/3.28084
#       8 acc['x']=0
#       9 acc['y']=0
#
# NameError: name 'result' is not defined

# %%
x = r*cos(lat)*cos(lon)
y = r*cos(lat)*sin(lon)
z = r*sin(lat)
acc['x'].iloc[i] =r*cos(result['lat'].iloc[i])*cos(result['lng'].iloc[i])

# %%
acc['z'].iloc[0]-acc['z'].iloc[1]

# %% [raw]
# acc['y'].iloc[0]-acc['y'].iloc[1]

# %%
acc

# %%
result['lat'].iloc[1]

# %%
result['lng'].iloc[1]

# %%
def lla_to_ecef_1X(lat, lon, alt):
    # see http://www.mathworks.de/help/toolbox/aeroblks/llatoecefposition.html
    rad = np.float64(6378137.0)        # Radius of the Earth (in meters)
    f = np.float64(1.0/298.257223563)  # Flattening factor WGS84 Model
    cosLat = np.cos(lat)
    sinLat = np.sin(lat)
    FF     = (1.0-f)**2
    C      = 1/np.sqrt(cosLat**2 + FF * sinLat**2)
    S      = C * FF

    x = (rad * C + alt)*cosLat * np.cos(lon)
    y = (rad * C + alt)*cosLat * np.sin(lon)
    z = (rad * S + alt)*sinLat
    return x

# %%
def lla_to_ecef_1Y(lat, lon, alt):
    # see http://www.mathworks.de/help/toolbox/aeroblks/llatoecefposition.html
    rad = np.float64(6378137.0)        # Radius of the Earth (in meters)
    f = np.float64(1.0/298.257223563)  # Flattening factor WGS84 Model
    cosLat = np.cos(lat)
    sinLat = np.sin(lat)
    FF     = (1.0-f)**2
    C      = 1/np.sqrt(cosLat**2 + FF * sinLat**2)
    S      = C * FF

    x = (rad * C + alt)*cosLat * np.cos(lon)
    y = (rad * C + alt)*cosLat * np.sin(lon)
    z = (rad * S + alt)*sinLat
    return y

# %%
def lla_to_ecef_1Z(lat, lon, alt):
    # see http://www.mathworks.de/help/toolbox/aeroblks/llatoecefposition.html
    rad = np.float64(6378137.0)        # Radius of the Earth (in meters)
    f = np.float64(1.0/298.257223563)  # Flattening factor WGS84 Model
    cosLat = np.cos(lat)
    sinLat = np.sin(lat)
    FF     = (1.0-f)**2
    C      = 1/np.sqrt(cosLat**2 + FF * sinLat**2)
    S      = C * FF

    x = (rad * C + alt)*cosLat * np.cos(lon)
    y = (rad * C + alt)*cosLat * np.sin(lon)
    z = (rad * S + alt)*sinLat
    return z

# %%
CoordXYZ=pd.DataFrame()
CoordXYZ['x']=lla_to_ecef_1X(np.radians(result['lat']) , np.radians(result['lng']), np.radians(result['alt']))
CoordXYZ['y']=lla_to_ecef_1Y(np.radians(result['lat']) , np.radians(result['lng']), np.radians(result['alt']))
CoordXYZ['z']=lla_to_ecef_1Z(np.radians(result['lat']) , np.radians(result['lng']), np.radians(result['alt']))

# %%
CoordXYZ

# %%
CoordXYZ['x'].iloc[0]-CoordXYZ['x'].iloc[1]
# Out:
# -57.451175461057574

# %%
CoordXYZ['y'].iloc[0]-CoordXYZ['y'].iloc[1]
# Out:
# -26.77081345859915

# %%
plt.plot(CoordXYZ['y'].values )

# %%
plt.plot(CoordXYZ['x'].values )

# %%
plt.plot(CoordXYZ['z'].values )

# %%
CoordXYZ['date']=result['date']
CoordXYZ['heure']=result['heure']

# %%
CoordXYZ
# Out:
#                  x             y             z        date     heure
# 0    -2.167877e+06  4.386507e+06  4.077679e+06  2008-10-25  00:36:54
# 1    -2.167819e+06  4.386534e+06  4.077681e+06  2008-10-25  00:37:37
# 2    -2.167701e+06  4.386601e+06  4.077673e+06  2008-10-25  00:38:16
# 3    -2.167624e+06  4.386647e+06  4.077666e+06  2008-10-25  00:38:59
# 4    -2.167575e+06  4.386673e+06  4.077662e+06  2008-10-25  00:39:49
# 5    -2.167492e+06  4.386713e+06  4.077663e+06  2008-10-25  00:40:41
# 6    -2.167410e+06  4.386756e+06  4.077661e+06  2008-10-25  00:41:40
# 7    -2.167310e+06  4.386817e+06  4.077649e+06  2008-10-25  00:42:33
# 8    -2.167270e+06  4.386840e+06  4.077646e+06  2008-10-25  00:43:22
# 9    -2.167139e+06  4.386908e+06  4.077643e+06  2008-10-25  00:43:57
# 10   -2.166981e+06  4.386945e+06  4.077688e+06  2008-10-25  00:44:25
# 11   -2.166858e+06  4.386977e+06  4.077717e+06  2008-10-25  00:44:58
# 12   -2.166860e+06  4.386977e+06  4.077717e+06  2008-10-25  00:45:48
# ...

# %%
plt.plot(CoordXYZ['heure'].values,CoordXYZ['x'].values )

# %%
j= CoordXYZ.loc[CoordXYZ['date']=="2008-10-26",:]

# %%
plt.plot(j['heure'].values,j['x'].values )

# %%
plt.plot(j['heure'].values,j['y'].values )

# %%
plt.plot(j['heure'].values,j['z'].values )

# %%
traj1=pd.DataFrame()
traj1['x']=lla_to_ecef_1X(np.radians(df['lat']) , np.radians(df['lng']), np.radians(df['alt']))
traj1['y']=lla_to_ecef_1Y(np.radians(df['lat']) , np.radians(df['lng']), np.radians(df['alt']))
traj1['z']=lla_to_ecef_1Z(np.radians(df['lat']) , np.radians(df['lng']), np.radians(df['alt']))
traj1['date']=test['date']
traj1['heure']=test['time']

# %%
len(test)
# Out:
# 538

# %%
plt.plot(traj1['y'].values )

# %%
traj2=traj1[0:10000]

# %%
plt.plot( traj2['y'].values )

# %%
def distance_on_geoid(lat1, lon1,  lat2, lon2) :
 
    
  
 
    
    r = 6378100;
 

    rho1 = r * np.cos(np.radians(lat1));
    z1 = r * np.sin(np.radians(lat1));
    x1 = rho1 * np.cos(np.radians(lon1));
    y1 = rho1 * np.sin(np.radians(lon1));
 

    rho2 = r * np.cos(np.radians(lat2));
    z2 = r * np.sin(np.radians(lat2));
    x2 = rho2 * np.cos(np.radians(lon2));
    y2 = rho2 * np.sin(np.radians(lon2));
 
    dot = (x1 * x2 + y1 * y2 + z1 * z2);
    cos_theta = dot / (r * r);
 
    theta = np.arccos(cos_theta);
 
    
    return r * theta;

# %%
distance_on_geoid(39.0, 116,  38, 114)
# Out:
# 206754.35397898412

# %%
from pygeodesy.sphericalNvector import LatLon
from datetime import datetime


distance=[]
temps=[]
for i in range(0, len(result)-1):
    d=haversine(result.iloc[i,0],result.iloc[i,1], result.iloc[i+1,0],result.iloc[i+1,1])
    
    distance.append(d)

for i in range(0, len(result)-1):
    d=haversine(result.iloc[i,0],result.iloc[i,1], result.iloc[i+1,0],result.iloc[i+1,1])
    d1 = datetime.strptime(result.iloc[i,5], "%Y-%m-%d %H:%M:%S")
    d2 = datetime.strptime(result.iloc[i+1,5], "%Y-%m-%d %H:%M:%S")
    t=d2-d1
    temps.append(t)
    



temps
t1=[]
for t in temps:
    v=t.total_seconds()
    t1.append(v)
    
t1
t1h=[t/3600 for t in t1]


tempscum=[]
t2=0
for t in t1h:
    t2=t2+t
    tempscum.append(t2)
    

newList = [ a/b for a, b in zip(distance,t1h)]

# %%
mobilite=pd.DataFrame()
mobilite['vitesse km/h']= newList
### ecart entre 2 point 
mobilite['temps heure ecart ']= t1h
mobilite['distance ecart']=distance
mobilite['temps cum']=tempscum
mobilite1=mobilite[0:100]
plt.plot(mobilite1['temps cum'].values, mobilite1['vitesse km/h'].values )
mobilite
# Out:
#       vitesse km/h  temps heure ecart   distance ecart    temps cum
# 0        14.442053            0.005000        0.072210     0.005000
# 1        14.075941            0.005000        0.070380     0.010000
# 2         2.797011            0.006944        0.019424     0.016944
# 3         4.509287            0.006944        0.031314     0.023889
# 4         3.525442            0.006944        0.024482     0.030833
# 5         9.696555            0.006111        0.059257     0.036944
# 6         3.975966            0.008333        0.033133     0.045278
# 7         5.272897            0.008333        0.043941     0.053611
# 8         6.238515            0.008056        0.050255     0.061667
# 9         6.622078            0.007778        0.051505     0.069444
# 10        9.547899            0.006944        0.066305     0.076389
# 11        5.391958            0.006667        0.035946     0.083056
# 12        1.379828            0.006944        0.009582     0.090000
# ...

# %%
def haversine(lat1,lon1, lat2, lon2):
    """
    Calculate the great circle distance between two points 
    on the earth (specified in decimal degrees)
    """
    # convert decimal degrees to radians 
    lon1, lat1, lon2, lat2 = map(math.radians, [lon1, lat1, lon2, lat2])
    # haversine formula 
    dlon = lon2 - lon1 
    dlat = lat2 - lat1 
    a = math.sin(dlat/2)**2 + math.cos(lat1) * math.cos(lat2) * math.sin(dlon/2)**2
    c = 2 * math.asin(math.sqrt(a)) 
    km = 6367 * c
    return km

# %%
result['timestamp']=result['date']+" "+result['heure']

# %%
from datetime import datetime

d1 = datetime.strptime("2015-08-10 19:33:27.653", "%Y-%m-%d %H:%M:%S.%f")
d2 = datetime.strptime("2015-08-10 19:31:28.209", "%Y-%m-%d %H:%M:%S.%f")

print(d1 - d2)
# Out:
# 0:01:59.444000

# %%
result
# Out:
#             lat         lng  alt        date     heure            timestamp
# 0     39.996342  116.297778  179  2008-10-25  00:37:58  2008-10-25 00:37:58
# 1     39.996295  116.296932  191  2008-10-25  00:38:16  2008-10-25 00:38:16
# 2     39.996235  116.296109  206  2008-10-25  00:38:34  2008-10-25 00:38:34
# 3     39.996211  116.295883  202  2008-10-25  00:38:59  2008-10-25 00:38:59
# 4     39.996161  116.295521  175  2008-10-25  00:39:24  2008-10-25 00:39:24
# 5     39.996175  116.295234  172  2008-10-25  00:39:49  2008-10-25 00:39:49
# 6     39.996134  116.294540  158  2008-10-25  00:40:11  2008-10-25 00:40:11
# 7     39.996187  116.294157  185  2008-10-25  00:40:41  2008-10-25 00:40:41
# 8     39.996257  116.293649  193  2008-10-25  00:41:11  2008-10-25 00:41:11
# 9     39.996158  116.293073  191  2008-10-25  00:41:40  2008-10-25 00:41:40
# 10    39.996070  116.292479  182  2008-10-25  00:42:08  2008-10-25 00:42:08
# ...
